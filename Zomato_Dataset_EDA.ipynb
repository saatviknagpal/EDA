# %% [markdown]
# <a href="https://colab.research.google.com/github/saatviknagpal/EDA/blob/main/Zomato_Dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Zomato Dataset Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('zomato.csv',encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4394 entries, 0 to 4393
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         4394 non-null   int64
#  1   Restaurant Name       4394 non-null   object
#  2   Country Code          4394 non-null   int64
#  3   City                  4394 non-null   object
#  4   Address               4394 non-null   object
#  5   Locality              4394 non-null   object
#  6   Locality Verbose      4394 non-null   object
#  7   Longitude             4394 non-null   float64
#  8   Latitude              4394 non-null   float64
#  9   Cuisines              4385 non-null   object
#  10  Average Cost for two  4394 non-null   int64
#  11  Currency              4394 non-null   object
#  12  Has Table booking     4394 non-null   object
#  13  Has Online delivery   4394 non-null   object
#  14  Is delivering now     4394 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   4.394000e+03   4394.000000  4394.000000  4394.000000
# mean    9.028446e+06     27.283113    55.376435    25.872748
# std     8.745323e+06     69.219163    54.565049    10.493219
# min     5.300000e+01      1.000000  -157.948486   -38.634746
# 25%     3.017282e+05      1.000000    77.028818    28.434658
# 50%     5.600960e+06      1.000000    77.111097    28.532494
# 75%     1.831196e+07      1.000000    77.238927    28.634848
# max     1.850065e+07    216.000000   153.593331    52.008289
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           4394.000000  4393.000000       4393.000000   4393.000000
# mean             615.405781     1.951286          2.979308    231.038470
# std              612.208456     0.932071          1.400966    566.592104
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (4394, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    1
# Price range             1
# Aggregate rating        1
# Rating color            1
# Rating text             1
# Votes                   1
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_country=pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df,df_country,on='Country Code',how='left')

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
## To check data types
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range             float64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                   float64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Country.value_counts()
# Out:
# Country
# India            3770
# United States     434
# Brazil             60
# UAE                60
# Australia          24
# Phillipines        22
# Singapore          20
# Canada              4
# Name: count, dtype: int64

# %%
country_names = final_df.Country.value_counts().index

# %%
country_val=final_df.Country.value_counts().values

# %%
### Pie chart
plt.pie(country_val[:3], labels=country_names[:3], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b5e8c355b40>,
# ...
#  [Text(-1.027941961890189, 0.3915805446971914, 'India'),
#   Text(1.0096330376245424, -0.4366247007866589, 'United States'),
#   Text(1.0989253659564135, -0.04861111043334417, 'Brazil')],
#  [Text(-0.5606956155764667, 0.2135893880166498, '88.41%'),
#   Text(0.5507089296133867, -0.2381589277018139, '10.18%'),
#   Text(0.5994138359762256, -0.026515151145460453, '1.41%')])

# %%
## Observation: Zomato maximum records are from India after that USA and then United Kingdoms

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated           706
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             1
# 3                2.0          Red        Poor             1
# 4                2.1          Red        Poor             4
# 5                2.2          Red        Poor            13
# 6                2.3          Red        Poor            14
# 7                2.4          Red        Poor            39
# 8                2.5       Orange     Average            40
# 9                2.6       Orange     Average            67
# 10               2.7       Orange     Average            92
# 11               2.8       Orange     Average           132
# 12               2.9       Orange     Average           138
# 13               3.0       Orange     Average           189
# 14               3.1       Orange     Average           208
# ...

# %%
## Observation
## 1. When rating is between 4.5 to 4.9---> Excellent
## 2. When rating is between 4.0 to 4.4---> Very Good
## 3. When rating is between 3.5 to 3.9---> Good
## 4. When rating is between 2.5 to 3.4---> Average
## 5. When rating is between 1.8 to 2.4---> Poor

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x='Aggregate rating',y='Rating Count',data=ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.barplot(x='Aggregate rating',y='Rating Count',hue='Rating color',data=ratings, palette=['blue','red','orange','yellow','green','green'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
# Observation:
##    1. Not rated count is very high
##    2. Maximum number of rating are between 2.5 to 3.4

# %%
sns.countplot(x='Rating color',data=ratings, palette=['blue','red','orange','yellow','green','green'])
# Out:
# <ipython-input-39-3b27fcf89497>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color',data=ratings, palette=['blue','red','orange','yellow','green','green'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated           706
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             1
# 3                2.0          Red        Poor             1
# 4                2.1          Red        Poor             4
# 5                2.2          Red        Poor            13
# 6                2.3          Red        Poor            14
# 7                2.4          Red        Poor            39
# 8                2.5       Orange     Average            40
# 9                2.6       Orange     Average            67
# 10               2.7       Orange     Average            92
# 11               2.8       Orange     Average           132
# 12               2.9       Orange     Average           138
# 13               3.0       Orange     Average           189
# 14               3.1       Orange     Average           208
# ...

# %%
### Find the countries name that has given 0 rating
final_df[final_df['Aggregate rating']==0.0].groupby('Country').size().reset_index()
# Out:
#          Country    0
# 0         Brazil    5
# 1          India  698
# 2  United States    3

# %%
## 0bservations
## Maximum number of 0 ratings are from Indian customers

# %%
## Find out which currency is used by which country?
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df[['Country', 'Currency']].groupby(['Country', 'Currency']).size().reset_index()
# Out:
#          Country            Currency     0
# 0      Australia           Dollar($)    24
# 1         Brazil  Brazilian Real(R$)    60
# 2         Canada           Dollar($)     4
# 3          India  Indian Rupees(Rs.)  3770
# 4    Phillipines    Botswana Pula(P)    22
# 5      Singapore           Dollar($)    20
# 6            UAE  Emirati Diram(AED)    60
# 7  United States           Dollar($)   434

# %%
final_df[final_df['Has Online delivery']=='Yes'].groupby('Country').size().reset_index()
# Out:
#   Country     0
# 0   India  1127
# 1     UAE    28

# %%
## Observations:
## 1. Online deliveries are available in India and UAE

# %%
## Create a pie chart for top 5 cities distribution
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Faridabad', 'Ghaziabad', 'Bhubaneshwar',
#        'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati', 'Sharjah',
#        ...
#        'Trentham East', 'Vernonia', 'Victor Harbor', 'Vineland Station',
#        'Forrest', 'Weirton', 'Winchester Bay', 'Yorkton', 'Flaxton',
#        'Fernley'],
#       dtype='object', name='City', length=110)

# %%
plt.pie(final_df.City.value_counts().values[:5],labels=final_df.City.value_counts().index[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b5e86efe4a0>,
# ...
#  [Text(-0.22131073675194884, 1.0775071033632724, 'New Delhi'),
#   Text(-0.09295715476208954, -1.096065220403666, 'Gurgaon'),
#   Text(1.0400530955855254, -0.35817531791423923, 'Faridabad'),
#   Text(1.0976923949047719, -0.07121380602261289, 'Ghaziabad'),
#   Text(1.0997732281313919, -0.02233487598930765, 'Bhubaneshwar')],
#  [Text(-0.12071494731924481, 0.5877311472890576, '56.45%'),
#   Text(-0.05070390259750338, -0.5978537565838178, '34.41%'),
#   Text(0.5673016885011956, -0.19536835522594864, '7.73%'),
#   Text(0.5987413063116938, -0.038843894194152476, '0.77%'),
#   Text(0.5998763062534864, -0.012182659630531443, '0.65%')])

# %%
## Assignment
## Find the top 10 cuisines

final_df[['Cuisines']].groupby(['Cuisines']).size().reset_index().rename(columns={0:'Cuisines Count'}).sort_values(by='Cuisines Count',ascending=False).head(10).reset_index(drop=True)
# Out:
#                          Cuisines  Cuisines Count
# 0                    North Indian             353
# 1           North Indian, Chinese             211
# 2           North Indian, Mughlai             146
# 3                            Cafe             145
# 4                       Fast Food             131
# 5                         Chinese             126
# 6                          Bakery              89
# 7                Bakery, Desserts              77
# 8  North Indian, Mughlai, Chinese              71
# 9                         Mughlai              50
